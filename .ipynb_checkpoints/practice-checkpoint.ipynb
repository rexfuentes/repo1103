# %%
import numpy as np
import pandas as pd

# %%
np_2d = np.array([[2,3],[4,5]])
np_2d * np.array([2,0])
# Out:
# array([[4, 0],
#        [8, 0]])

# %%
np_2d = np.array([[2,3],[4,5]])
np_2d * np.array([2,1])
# Out:
# array([[4, 3],
#        [8, 5]])

# %%
np_2d = np.array([[2,3],[4,5]])
np_2d * np.array([1,0])
# Out:
# array([[2, 0],
#        [4, 0]])

# %%
x = [9, 2, 8, 4, 5]
x.remove(5)
x
# Out:
# [9, 2, 8, 4]

# %% [markdown]
# ### How to Add Links and Images in Markdown

# %% [markdown]
# [Link to PSA](https://psa.gov.ph/)

# %% [markdown]
# ![c](attachment:headshot.png)
